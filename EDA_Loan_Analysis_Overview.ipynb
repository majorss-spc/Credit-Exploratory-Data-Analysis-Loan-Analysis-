# %% [markdown]
# # 📊 Exploratory Data Analysis (EDA) - Loan Application Case Study
#
# ## 🔹 EDA Key Steps
#
# - **Importing and Cleaning Data**
# - **Univariate Analysis**
# - **Bivariate Analysis**
# - **Multivariate Analysis**
# - **Data Transformation**

# %% [markdown]
# ## 🧩 Problem Definition
#
# - Loan providing companies face difficulty giving loans to people due to insufficient or no credit history.
# - Some users take advantage of this by becoming defaulters.
# - Perform EDA to discover data patterns and ensure eligible applicants are not wrongly rejected.
# - If an applicant is **likely to repay**, rejecting their loan causes **loss of business**.
# - If an applicant is **likely to default**, approving the loan causes **financial loss**.
#
# This EDA will help identify those patterns and improve decision-making.

# %% [markdown]
# ## 📋 EDA Steps (Phase 1)
#
# 1. Import Dataset
# 2. Read Application CSV
# 3. Data Inspection on Application Dataset
# 4. Data Quality Check
# 5. Impute Missing Values
# 6. Check/Validate Data Types of Columns

# %% [markdown]
# ## 📋 EDA Steps (Phase 2)
#
# 7. Binning of Continuous Variables
# 8. Data Imbalance Check
# 9. Univariate Analysis
# 10. Plot on Categorical Columns
# 11. Plot on Numerical Columns

# %% [markdown]
# ## 📋 EDA Steps (Phase 3)
#
# 12. Bivariate & Multivariate Analysis
# 13. Correlation between Numerical Columns
# 14. Read Previous Application CSV and repeat all steps
# 15. Merge Application and Previous Application DataFrames
